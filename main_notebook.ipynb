# %%
import pandas as pd
import numpy as np
from clean import complete_clean
from model import lin_model, split, model_results, gboost_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import joblib
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("bmw.csv", index_col=0)

# %%
df = complete_clean(df)

# %%
df
# Out:
#       price     miles  ...  drive_type_electric  drive_type_hybri
# 0      4000  0.000010  ...                    0                 0
# 1      2795  0.000008  ...                    0                 0
# 2      1500  0.000007  ...                    0                 0
# 3     29000  0.000020  ...                    0                 0
# 4     24500  0.000029  ...                    0                 0
# ...     ...       ...  ...                  ...               ...
# 2975  23490  0.000029  ...                    0                 0
# 2976  22490  0.000042  ...                    0                 0
# 2977  20990  0.000056  ...                    0                 0
# 2978  20990  0.000038  ...                    0                 1
# 2979  20990  0.000017  ...                    0                 0
#
# [2861 rows x 64 columns]

# %%
X_train, X_test, y_train, y_test = split(df)

# %%
model, y_pred = lin_model(X_train, X_test, y_train)

# %%
r_score, mse, mae = model_results(y_test, y_pred)

# %%
print("R2 Score: {}".format(r_score))
print("MSE     : {}".format(mse))
print("MAE.    : {}".format(mae))
# Out:
# R2 Score: 0.8498218551933211
# MSE     : 24687904.804537524
# MAE.    : 3522.211169284468

# %%
joblib.dump(model, 'bmw_linear_model_new.sav')
# Out:
# ['bmw_linear_model_new.sav']

# %%
gboost_main_model, y_pred_gboost = gboost_model(X_train, X_test, y_train)

# %%
r_score_gboost, mse_gboost, mae_gboost = model_results(y_test, y_pred_gboost)

# %%
print("R2 Score: {}".format(r_score_gboost))
print("MSE     : {}".format(mse_gboost))
print("MAE.    : {}".format(mae_gboost))
# Out:
# R2 Score: 0.8628764376523977
# MSE     : 22541851.59934214
# MAE.    : 3408.353972062276

# %%
joblib.dump(gboost_main_model, "gboost_model.sav")
# Out:
# ['gboost_model.sav']
